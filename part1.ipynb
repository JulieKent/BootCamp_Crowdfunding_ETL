# %% [markdown]
# # Create Category and Subcategory DataFrames

# %%
import pandas as pd

# %%
# Extract and transform the excel data to create a category DataFrame 

campaign = pd.read_excel("Resources/crowdfunding.xlsx")
campaign.head()
# Out:
#    cf_id  contact_id                 company_name  \
# 0    147        4661   Baldwin, Riley and Jackson
# 1   1621        3765                     Odom Inc
# 2   1812        4187   Melton, Robinson and Fritz
# 3   2156        4941  Mcdonald, Gonzalez and Ross
# 4   1365        2199                Larson-Little
#
#                                            blurb    goal  pledged     outcome  \
# 0           Pre-emptive tertiary standardization     100        0      failed
# 1               Managed bottom-line architecture    1400    14560  successful
# 2   Function-based leadingedge pricing structure  108400   142523  successful
# 3  Vision-oriented fresh-thinking conglomeration    4200     2477      failed
# 4                      Proactive foreground core    7600     5265      failed
#
#    backers_count country currency  launched_at    deadline  staff_pick  \
# 0              0      CA      CAD   1581573600  1614578400       False
# ...

# %%
# Seperate the column "category & sub-category" values

category_df = campaign['category & sub-category'].str.split('/', expand=True)
category_df.columns = ['category', 'subcategory']

category_df
# Out:
#        category  subcategory
# 0          food  food trucks
# 1         music         rock
# 2    technology          web
# 3         music         rock
# 4       theater        plays
# ..          ...          ...
# 995        food  food trucks
# 996     theater        plays
# 997     theater        plays
# 998       music   indie rock
# 999        food  food trucks
#
# [1000 rows x 2 columns]

# %%
# Extract unique categories and subcategories
unique_categories = category_df['category'].unique()
unique_subcategories = category_df['subcategory'].unique()

# %%
# Create a category DataFrame with the "category_id" column
category_df = pd.DataFrame({"category_id": [f"cat{i+1}" for i in range(len(unique_categories))],
                            "category_name": unique_categories})

category_df
# Out:
#   category_id category_name
# 0        cat1          food
# 1        cat2         music
# 2        cat3    technology
# 3        cat4       theater
# 4        cat5  film & video
# 5        cat6    publishing
# 6        cat7         games
# 7        cat8   photography
# 8        cat9    journalism

# %%
# Export the category DataFrame to a CSV file
category_df.to_csv("Outputs//category.csv", index=False)

# %%
# Create a subcategory DataFrame with the "subcategory_id" column
subcategory_df = pd.DataFrame({"subcategory_id": [f"subcat{i+1}" for i in range(len(unique_subcategories))],
                            "subcategory_name": unique_subcategories})

# %%
# Export the subcategory DataFrame to a CSV file
subcategory_df.to_csv("Outputs//subcategory.csv", index=False)
